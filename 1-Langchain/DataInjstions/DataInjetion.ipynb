# %%
## text Loader

# %%
from langchain_community.document_loaders import TextLoader
TextLoader('speech.txt').load()
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Good morning everyone,\n\nToday I want to talk about something very simple but very powerful â€” believing in yourself.\n\nIn life, we all face challenges. Sometimes we feel confused, sometimes we fail, and sometimes we feel like giving up. But the truth is, failure is not the end. It is just a lesson. Every mistake teaches us something important.\n\nSuccess does not come in one day. It comes from small efforts we make every day. If you practice daily, learn daily, and improve daily, you will definitely grow. Growth is not about being better than others. It is about being better than yesterday.\n\nMany times, we compare ourselves with others. But remember, everyone has a different journey. Someone may run fast, someone may walk slowly â€” but what matters is that we keep moving forward.\n\nConfidence is not about knowing everything. Confidence is about believing that you can learn anything.\n\nSo never stop learning. Never stop trying. And most importantly, never stop believing in yourself.\n\nBecause the moment you believe in yourself, the world will start believing in you too.\n\nThank you.')]

# %%
loader=TextLoader("speech.txt")
loader

# %%
text_documents=loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Good morning everyone,\n\nToday I want to talk about something very simple but very powerful â€” believing in yourself.\n\nIn life, we all face challenges. Sometimes we feel confused, sometimes we fail, and sometimes we feel like giving up. But the truth is, failure is not the end. It is just a lesson. Every mistake teaches us something important.\n\nSuccess does not come in one day. It comes from small efforts we make every day. If you practice daily, learn daily, and improve daily, you will definitely grow. Growth is not about being better than others. It is about being better than yesterday.\n\nMany times, we compare ourselves with others. But remember, everyone has a different journey. Someone may run fast, someone may walk slowly â€” but what matters is that we keep moving forward.\n\nConfidence is not about knowing everything. Confidence is about believing that you can learn anything.\n\nSo never stop learning. Never stop trying. And most importantly, never stop believing in yourself.\n\nBecause the moment you believe in yourself, the world will start believing in you too.\n\nThank you.')]

# %%
# how to read a pdf file 

from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("random_generated_pdf.pdf")
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-12T05:35:21+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-02-12T05:35:21+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'random_generated_pdf.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Random Generated PDF Document\nGenerated on: 2026-02-12 05:35:21\nRandom Thoughts:\nSmall steps every day lead to big achievements.\nSmall steps every day lead to big achievements.\nSmall steps every day lead to big achievements.\nThis is a randomly generated sentence for your PDF file.\nConsistency is the key to success in any field.\nRandom Numbers List:\n\x7f\n19\n\x7f\n1\n\x7f\n9\n\x7f\n93\n\x7f\n43\n\x7f\n18\n\x7f\n79\n\x7f\n81\n\x7f\n57\n\x7f\n69\nRandom Data Table:\nIndex\nRandom Value\n1\n149\n2\n225\n3\n456\n4\n595\n5\n561')]

# %%
type(docs)
# Out:
# list
